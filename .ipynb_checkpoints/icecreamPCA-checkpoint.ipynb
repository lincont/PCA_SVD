# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix
from sklearn.decomposition import PCA
import seaborn as sns

# %matplotlib notebook

# %%
#sundae ingredients: ice cream, chocolate syrup, caramel syrup, marshmallow syrup, whipped cream, nuts, cherry, banana
numrows = 1000
#ice cream:
flavors = {0:'sweet cream',1:'vanilla',2:'mexican vanilla',3:'triplemex'}
icecreamcat = np.random.randint(0,len(flavors),numrows)
icecreamflav = [flavors[x] for x in icecreamcat]

# %%
#sundae ingredients: ice cream, chocolate syrup, caramel syrup, marshmallow syrup, whipped cream, nuts, cherry, banana
numrows = 1000
#ice cream:
flavors = {0:'sweet cream',1:'vanilla',2:'mexican vanilla',3:'triplemex'}
icecreamcat = np.random.randint(0,len(flavors),numrows)
icecreamflav = [flavors[x] for x in icecreamcat]

#syrups can come in 1/2 pump units, up to 3 (what madman would have more than three?!)
hotfudge = abs(np.random.normal(2,1,numrows)) #mean 1, stdev 1
caramel = abs(1/hotfudge - np.random.normal(0,0.5,numrows)) #mean 0, stdev 2
fluff = abs(hotfudge - np.random.randint(0,2,numrows)/2) #random 0-2, in 0.5 
whip = abs(np.random.normal(1,0.2,numrows)) #mean 1, stdev 0.2
nuts = abs(np.random.normal(0.5,0.5,numrows)) #mean 0.5, stdev 0.5

#discrete number of cherries
cherry = np.random.randint(0,2,numrows)

#number of banana slices (est. 20 slices per banana)
banana = np.random.randint(0,20,numrows)

sundae_df = pd.DataFrame(icecreamflav,columns=['flavor'])
sundae_df['ice_cream'] = icecreamcat
sundae_df['hot_fudge'] = hotfudge
sundae_df['caramel'] = caramel
sundae_df['marshmallow'] = fluff
sundae_df['whipped_cream'] = whip
sundae_df['nuts'] = nuts
sundae_df['cherry'] = cherry
sundae_df['banana'] = banana
sundae_df[:10]
# Out:
#             flavor  ice_cream  hot_fudge   caramel  marshmallow  \
# 0          vanilla          1   1.243824  1.565381     1.243824
# 1  mexican vanilla          2   3.787563  0.138393     3.787563
# 2          vanilla          1   2.283493  0.010894     1.783493
# 3      sweet cream          0   1.720582  0.297656     1.720582
# 4      sweet cream          0   1.345497  1.303062     0.845497
# 5  mexican vanilla          2   4.983898  0.047782     4.483898
# 6      sweet cream          0   0.454186  1.739117     0.045814
# 7        triplemex          3   2.728926  0.740467     2.228926
# 8      sweet cream          0   3.460534  0.434698     3.460534
# 9          vanilla          1   1.932262  1.099819     1.932262
#
#    whipped_cream      nuts  cherry  banana
# 0       1.153816  0.314442       1       8
# 1       0.963829  0.062876       1      17
# 2       0.762426  0.976952       0       2
# 3       0.859230  0.984841       1       6
# 4       0.770012  0.865205       1       1
# 5       1.126843  0.863542       0       0
# 6       1.079506  0.000170       1      18
# 7       0.943648  1.822857       1      16
# 8       1.121998  0.882748       0      12
# 9       0.858202  0.914606       1       2

# %%
#calorie calculator
# ice cream = 137
# hot fudge = 130
# caramel = 120
# marshmallow = 91
# whipped cream = 8
# nuts = 50
# cherry = 8
# banana = 5
calories = sundae_df['ice_cream']*137 + sundae_df['hot_fudge']*130 + sundae_df['caramel']*120 + \
    sundae_df['marshmallow']*91 + sundae_df['whipped_cream']*8 + sundae_df['nuts']*50 + sundae_df['cherry']*8 \
    + sundae_df['banana']*5
sundae_df['calories'] = calories

# %%
sundae_df.head()
# Out:
#             flavor  ice_cream  hot_fudge   caramel  marshmallow  \
# 0          vanilla          1   1.243824  1.565381     1.243824
# 1  mexican vanilla          2   3.787563  0.138393     3.787563
# 2          vanilla          1   2.283493  0.010894     1.783493
# 3      sweet cream          0   1.720582  0.297656     1.720582
# 4      sweet cream          0   1.345497  1.303062     0.845497
#
#    whipped_cream      nuts  cherry  banana     calories
# 0       1.153816  0.314442       1       8   672.683543
# 1       0.963829  0.062876       1      17  1231.513154
# 2       0.762426  0.976952       0       2   662.406157
# 3       0.859230  0.984841       1       6   510.083196
# 4       0.770012  0.865205       1       1   470.642530

# %%
scatter_matrix(sundae_df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# <img src="data:image/png;base64,...">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12b799b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a68d208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a657908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a27c400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1295d65f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1290953c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a7740b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12a26c208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12b77b240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12a72a630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1290d97b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129094b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124fe70b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125830b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12586beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1258b9ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128035cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128d26d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x128d60b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128daed68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128f162b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128f529e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128f9bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x128fdc9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12902c4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d0ac630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d0f3780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d135470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d1816a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d304ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d345320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d390908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d3d1320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d41add8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d457f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d4a40b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d4dbd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d528f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d57a4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d5b4c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d705240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d73fc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d78f710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d7c9860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d8149b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d8506a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d89e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d8e7dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12da29550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12da72b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12dab4550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12dc03048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12dc3e198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12dc882e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12dcbff98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12de12208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12de5e710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12de97e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12dee6470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12df23e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12df70940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12dfaca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12dff8be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12e2348d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12e281b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12e2d3048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12e40c780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12e456d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12e498780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12e4e6278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d71c5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cb51c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12cb3f0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12e559a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12e5a9438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129224f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129273978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1292aec88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1292fe898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1293398d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129383828>]], dtype=object)

# %%
print(len(sundae_df[sundae_df['calories'] > 1500]))
print(len(sundae_df[sundae_df['calories'] > 2500]))
print(len(sundae_df[sundae_df['calories'] > 3000]))
print(len(sundae_df[sundae_df['calories'] > 4000]))
print(len(sundae_df[sundae_df['calories'] > 5000]))
print(len(sundae_df[sundae_df['calories'] > 8000]))
# Out:
# 48
# 12
# 7
# 6
# 6
# 4

# %%
sundae_df.hist(column='calories',bins=200)
# Out:
# <img src="data:image/png;base64,...">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12f2bc908>]], dtype=object)

# %%
#prep data
del sundae_df['flavor']
X = sundae_df[sundae_df['calories'] < 3000]
X = X/np.std(X)

# %%
pca = PCA()
pca.fit(X)
# Out:
# PCA(copy=True, n_components=None, whiten=False)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [  2.74050919e-01   1.82415768e-01   1.22522764e-01   1.12430066e-01
#    1.08139309e-01   1.05387999e-01   9.15516029e-02   3.50157122e-03
#    9.88451158e-33]

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)

comps = range(len(pca.explained_variance_ratio_))
ax.bar(comps,np.cumsum(pca.explained_variance_ratio_))
# Out:
# <img src="data:image/png;base64,...">
# <Container object of 9 artists>

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)

lcomps = [x for x in comps]
sns.barplot(lcomps,np.cumsum(pca.explained_variance_ratio_))
# Out:
# <img src="data:image/png;base64,...">

# %%
print(pca.components_)
# Out:
# [[ 0.15591471  0.61171643 -0.26224623  0.60892308  0.0292819   0.02354738
#   -0.0143181   0.01304581  0.40018259]
#  [-0.53401017  0.16604925 -0.53894206  0.13584563 -0.03413833 -0.10170016
#   -0.02347172 -0.11459158 -0.59427074]
#  [ 0.24409674 -0.01634613  0.00692164 -0.01253171 -0.29605118 -0.5897369
#   -0.36949598 -0.60639301  0.01640015]
#  [ 0.0882345   0.01197217 -0.07301871 -0.01662941 -0.67118618 -0.19634182
#    0.69293157  0.1312725   0.00595321]
#  [-0.19420376  0.03727971  0.14681931  0.0492736  -0.60323038  0.64920486
#   -0.31822159 -0.22035779  0.04165264]
#  [-0.26986522  0.0705213   0.31211989  0.09253006  0.28784071  0.12062824
#    0.50840261 -0.6745352   0.07310591]
#  [-0.59572929  0.11152728  0.53368455  0.18436303 -0.11419518 -0.40497507
#   -0.14968126  0.30427599  0.14773511]
#  [ 0.05317982 -0.69069093 -0.01490872  0.71761115 -0.00669369  0.01243111
#    0.01773931  0.00359968 -0.06635461]
#  [-0.39356244 -0.31931928 -0.48101198 -0.22445462 -0.00392913 -0.05084701
#   -0.01026019 -0.07484321  0.67311497]]

# %%
pca_df = pd.DataFrame(pca.components_, columns = sundae_df.columns)
pca_df.head()
# Out:
#    ice_cream  hot_fudge   caramel  marshmallow  whipped_cream      nuts  \
# 0   0.155915   0.611716 -0.262246     0.608923       0.029282  0.023547
# 1  -0.534010   0.166049 -0.538942     0.135846      -0.034138 -0.101700
# 2   0.244097  -0.016346  0.006922    -0.012532      -0.296051 -0.589737
# 3   0.088235   0.011972 -0.073019    -0.016629      -0.671186 -0.196342
# 4  -0.194204   0.037280  0.146819     0.049274      -0.603230  0.649205
#
#      cherry    banana  calories
# 0 -0.014318  0.013046  0.400183
# 1 -0.023472 -0.114592 -0.594271
# 2 -0.369496 -0.606393  0.016400
# 3  0.692932  0.131272  0.005953
# 4 -0.318222 -0.220358  0.041653

# %%
pca_df.iloc[0]
# Out:
# ice_cream        0.155915
# hot_fudge        0.611716
# caramel         -0.262246
# marshmallow      0.608923
# whipped_cream    0.029282
# nuts             0.023547
# cherry          -0.014318
# banana           0.013046
# calories         0.400183
# Name: 0, dtype: float64

# %%
pc1 = pca.components_[0]
pc1
# Out:
# array([ 0.15591471,  0.61171643, -0.26224623,  0.60892308,  0.0292819 ,
#         0.02354738, -0.0143181 ,  0.01304581,  0.40018259])

# %%
figure = plt.figure(figsize=(12,6))
ax = figure.add_subplot(111)

x = range(len(sundae_df.columns))
xzero = range(-1,10)
zero = [0 for xi in xzero]
ax.bar(x,pca_df.iloc[0,:])
ax.plot(xzero,zero,'m--')
ax.set_xlim(-1,9)
#ax.x_labels
# Out:
# <img src="data:image/png;base64,...">
# (-1, 9)

# %%
fig = plt.figure(figsize=(12,18))
for i in range(7):
    ax = fig.add_subplot(7,1,i+1)
    pca_df.iloc[i].T.plot(sharex=True,ax=ax,kind='bar',alpha=0.75)
    zero = [0 for x in pca_df.columns]
    xzero = range(len(zero))
    ax.plot(xzero,zero,'k--')
    ax.set_title('PC'+str(i+1))
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# #calories are correlated mostly with fudge, caramel, and fluff, based on scatter matrix, but because they
# #are constructed randomly, those are not correlated with each other.  Need to add in correlations and
# #anticorrelations to make sure we see relationships in the data.
#
# To Do:
# PCA good for dimensionality reduction:
#     - plot of cumsum
# PCA good for coordinate transformation:
#     - recreate a single data point out of PCs
# PCA good for interpreting:
#     - line plot
